# %% [markdown]
# ## Numpy vs Pandas
#
# NumPy is best for numerical calculations, while Pandas is ideal for data cleaning, manipulation, and tabular data handling.
# Both work together, but Pandas adds structure and convenience for real-world datasets.

# %% [markdown]
# ## What is Pandas?
#
# Pandas is a Python library for data manipulation and analysis.

# %% [markdown]
# ### DataFrame
# like Excel tables (rows & columns)

# %%
import pandas as pd

# %%
# Series: 1D data
data = [10, 20, 30, 40]
s = pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# DataFrame: 2D table
data = {
    'Name': ['Ali', 'Sara', 'Zeeshan'],
    'Age': [25, 22, 28],
    'City': ['Lahore', 'Karachi', 'Islamabad']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age       City
# 0      Ali   25     Lahore
# 1     Sara   22    Karachi
# 2  Zeeshan   28  Islamabad

# %%
# Access a column
print(df['Name'])
# Out:
# 0        Ali
# 1       Sara
# 2    Zeeshan
# Name: Name, dtype: object

# %%
# Access a column
print(df['City'])
# Out:
# 0       Lahore
# 1      Karachi
# 2    Islamabad
# Name: City, dtype: object

# %%
# Access multiple columns
print(df[['Name', 'City']])
# Out:
#       Name       City
# 0      Ali     Lahore
# 1     Sara    Karachi
# 2  Zeeshan  Islamabad

# %%
# Access rows by index
print(df.loc[0])    # first row
# Out:
# Name       Ali
# Age         25
# City    Lahore
# Name: 0, dtype: object

# %%
print(df.iloc[1])   # second row
# Out:
# Name       Sara
# Age          22
# City    Karachi
# Name: 1, dtype: object

# %%
# Statistics
print(df['Age'].mean())   # average age
print(df['Age'].sum())    # sum of ages
# Out:
# 25.0
# 75

# %%
print(df[df['Age'] > 23])   # rows where Age > 23
# Out:
#       Name  Age       City
# 0      Ali   25     Lahore
# 2  Zeeshan   28  Islamabad

# %%
# Add a new column
df['Country'] = 'Pakistan'
print(df)
# Out:
#       Name  Age       City   Country
# 0      Ali   25     Lahore  Pakistan
# 1     Sara   22    Karachi  Pakistan
# 2  Zeeshan   28  Islamabad  Pakistan

# %%
# Write DataFrame to CSV
df.to_csv('output.csv', index=False)

# %%
# Read CSV file
df = pd.read_csv('output.csv')

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\User\\Desktop\\prac.1'

# %%
import pandas as pd

health_data = pd.read_csv("output.csv", header=0, sep=",")

print(health_data.info())
# Out:
#       Name  Age       City   Country
# 0      Ali   25     Lahore  Pakistan
# 1     Sara   22    Karachi  Pakistan
# 2  Zeeshan   28  Islamabad  Pakistan

# %%
print(health_data.info())
