# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

# %%
Days = ["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]
Sales = [120, 150, 90, 200, 170, 300, 250]

plt.plot(Days,Sales)

plt.xlabel("Days")

plt.ylabel("Sales")

plt.title("Weekly Sales")

plt.show()

# %%
#scoreboard

import matplotlib.pyplot as plt
import pandas as pd

data={
    'col1':[1,2,3,4,5],
    'col2':[2,4,5,6,8],
    'col3':[6,0,9,8,2]
}

dat=pd.DataFrame(data)

print(dat)

count_column = dat.shape[1]
print(count_column)
# Out:
#    col1  col2  col3
# 0     1     2     6
# 1     2     4     0
# 2     3     5     9
# 3     4     6     8
# 4     5     8     2
# 3
