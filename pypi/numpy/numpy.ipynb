# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 1.9 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/12.8 MB 1.9 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/12.8 MB 968.0 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.3/12.8 MB 1.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.6/12.8 MB 1.4 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.8 MB 1.6 MB/s eta 0:00:07
#    -------- ------------------------------- 2.6/12.8 MB 1.7 MB/s eta 0:00:06
#    --------- ------------------------------ 2.9/12.8 MB 1.8 MB/s eta 0:00:06
# ...

# %%
import numpy as np

a=np.array([[3,4],[5,6]])
b=np.array([[3,9],[5,8]])

c=a*b

print(c)
# Out:
# [[ 9 36]
#  [25 48]]

# %%
import numpy as np 

x=np.array([1,2,3,4])
